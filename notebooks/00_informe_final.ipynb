# %% [markdown]
# ## 1. EDA
#
#
#  comportamiento global de los **puntos Fantasy (FPTS)** por posición en la liga:
#
# - **Promedio de FPTS por posición**:
#   - DST (Defensas): 24.8
#   - Kickers: 20.5
#   - QBs: 18.8
#   - RBs: 10.7
#   - TEs: 4.7
#   - WRs: 8.2

# %% [markdown]
# - **Promedio de FPTS por juego**:
#   - DST: 6.22
#   - Kickers: 5.54
#   - QBs: 5.35
#   - RBs: 2.88
#   - TEs: 1.34
#   - WRs: 2.18
#
#   - **Cantidad de jugadores por posición**:
#   - WR es la posición con más jugadores (325), seguida por RB (208) y TE (192).
#   - DST es la menos numerosa con 34 equipos analizados.
#
# En resumen, las **defensas y los kickers** son los que generan **mayores puntos promedio**, aunque las posiciones ofensivas tienen una mayor cantidad de jugadores y variabilidad.

# %% [markdown]
# ## 2. Jugadores Destacados por Posición Ofensiva
#
# El análisis de los **Top 5 jugadores por posición ofensiva** muestra:
#
# - Los **QBs** dominan en FPTS (Josh Allen, Lamar Jackson, Mahomes).
# - En **RBs**, destacan Christian McCaffrey, Jonathan Taylor y Bijan Robinson.
# - **TEs** más productivos: Hunter Henry y Dalton Kincaid.
# - En **WRs**, Amon-Ra St. Brown y Puka Nacua sobresalen.

# %% [markdown]
# ## 3. Análisis Defensivo
#
# ### Top 10 Defensas por Puntos Fantasy
# 1. Seattle Seahawks (49 pts)
# 2. Jacksonville Jaguars (46 pts)
# 3. Minnesota Vikings (44 pts)
# 4. Philadelphia Eagles (35 pts)
# 5. Detroit Lions (35 pts)
#
# La **media de puntos defensivos por juego** fue de **6.22 FPTS**, con una distribución bastante dispersa entre equipos.

# %% [markdown]
# ### Matriz de Correlación
# - **Sacks (SACK)** tiene la correlación más fuerte con los **FPTS (0.46)**.
# - **Intercepciones (INT)** también muestran una correlación positiva (0.55).
# - Otras métricas (fumbles, TDs defensivos, safeties) tienen correlaciones bajas o negativas.
#
# ### Comparación de Estadísticas Defensivas
# - Seattle y Detroit lideran en **sacks**.
# - Jacksonville sobresale en **intercepciones**.
# - Los **TDs defensivos y de equipos especiales** son poco frecuentes, pero impactan significativamente los puntos Fantasy.

# %% [markdown]
# ## 4. Running Backs (RBs)
#
# ### Top 15 RBs por Puntos Fantasy
# - **James Cook III (BUF)**: 79 pts
# - **Jonathan Taylor (IND)**: 77 pts
# - **Bijan Robinson (ATL)**: 70 pts
#
# ### Insights:
# - Promedio de **10.7 FPTS** por jugador.
# - Media de **2.1 yardas por acarreo (Y/A)**.
# - Correlación positiva entre **yardas terrestres y FPTS**, con los TDs como principal impulsor de puntos.
# - Los RBs más productivos son aquellos con equilibrio entre **acarreos y recepciones** (ej. McCaffrey, Bijan Robinson).
#
# ### Comparación (Top 10 RBs)
# Se observa variabilidad entre jugadores “terrestres” (Taylor, Jacobs) y duales (McCaffrey, Gibbs), mostrando diferentes estilos de producción fantasy.
#
# ---

# %% [markdown]
# ## 5. Tight Ends (TEs)
#
# ### Top 15 TEs por Puntos Fantasy
# - **Hunter Henry (NE)**: 38 pts
# - **Dalton Kincaid (BUF)**: 36 pts
# - **Tucker Kraft (GB)**: 35 pts
#
# ### Insights:
# - Promedio general de **4.7 FPTS**.
# - Promedio de **3.9 yardas por recepción (Y/R)**.
# - Fuerte relación entre **targets y recepciones** → más volumen = más puntos.
# - La mayoría de TEs tiene bajo número de touchdowns, siendo el principal factor limitante en FPTS.
#
# ---

# %% [markdown]
# ## 🔎 Conclusiones EDA
#
# - **Defensas y Kickers** lideran en eficiencia promedio, pero las posiciones ofensivas (QB, RB, WR) tienen mayor impacto en el total de puntos Fantasy por la cantidad de jugadores disponibles.
# - **Correlaciones clave**:
#   - En defensas, los **sacks e intercepciones** son los indicadores más valiosos.
#   - En ofensiva, el **volumen (acarreos, targets, recepciones)** se asocia fuertemente con los FPTS.
# - Los jugadores “dual threat” (capaces de correr y recibir) dominan el top de productividad Fantasy.
#
# ---
